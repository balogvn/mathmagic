# %%
from mathmagic import calculator
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from mathmagic import calculator
#
# ModuleNotFoundError: No module named 'mathmagic'
