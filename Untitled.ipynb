# %%
from mathmagic import calculator

# %%
# Addition
result = mathmagic/calculator.add(5, 7)
print(result) # 12
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 # Addition
# ----> 2 result = mathmagic/calculator.add(5, 7)
#       3 print(result)
#
# NameError: name 'mathmagic' is not defined

# %%
# Addition
result = calculator.subtract(5, 7)
print(result) #
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 2
#       1 # Addition
# ----> 2 result = calculator.subtract(5, 7)
#       3 print(result)
#
# AttributeError: module 'mathmagic.calculator' has no attribute 'subtract'

# %%
# calculate average
scores = [85, 90, 78]
avg = calculator.average(scores)
print(avg)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 3
#       1 # calculate average
#       2 scores = [85, 90, 78]
# ----> 3 avg = calculator.average(scores)
#       4 print(avg)
#
# AttributeError: module 'mathmagic.calculator' has no attribute 'average'
